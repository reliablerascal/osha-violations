# %% [markdown]
# # Analyze OSHA Violations for Springfield, IL 2018-2022
# 5 December 2023

# %% [markdown]
# ### Summary of Findings
# <ul>
#     <li>Bunn-O-Matic has the most number of inspection citations in Springfield from 2018 to 2022, with 9 at their 1400 Adlai Stevenson facility and 1 at the 1200 Bunn Ave.
#         <li>Their total penalties, $59,490 plus $13,674. About half paid
#             </ul>

# %% [markdown]
# ### Next Steps for Improving This Analysis
# ...

# %% [markdown]
# # 1) Summarize OSHA Violations

# %%
import pandas as pd

# %% [markdown]
# ### import and review inspections and violations

# %%
df_inspections = pd.read_csv("../data/springfield-il-inspections-2018-2022-edit.csv")
df_inspections_simple = df_inspections[['ACTIVITY_NR','ESTAB_NAME','SITE_CITY','SITE_ZIP','SITE_ADDRESS','INSP_TYPE','INSP_DESC']]
#df_inspections.dtypes
df_inspections_simple.dtypes
# Out:
# ACTIVITY_NR      int64
# ESTAB_NAME      object
# SITE_CITY       object
# SITE_ZIP         int64
# SITE_ADDRESS    object
# INSP_TYPE       object
# INSP_DESC       object
# dtype: object

# %%
df_violations = pd.read_csv("../data/springfield-il-violations-2018-2022.csv")
df_violations.dtypes
# Out:
# Unnamed: 0                int64
# ACTIVITY_NR               int64
# CITATION_ID              object
# DELETE_FLAG              object
# STANDARD                 object
# VIOL_TYPE                object
# ISSUANCE_DATE            object
# ABATE_DATE               object
# ABATE_COMPLETE          float64
# CURRENT_PENALTY         float64
# INITIAL_PENALTY           int64
# CONTEST_DATE             object
# FINAL_ORDER_DATE         object
# NR_INSTANCES              int64
# NR_EXPOSED                int64
# REC                      object
# GRAVITY                 float64
# EMPHASIS                float64
# HAZCAT                  float64
# FTA_INSP_NR             float64
# FTA_ISSUANCE_DATE       float64
# FTA_PENALTY             float64
# FTA_CONTEST_DATE        float64
# FTA_FINAL_ORDER_DATE    float64
# HAZSUB1                 float64
# HAZSUB2                 float64
# HAZSUB3                 float64
# HAZSUB4                 float64
# HAZSUB5                 float64
# LOAD_DT                  object
# RNUM                      int64
# dtype: object

# %% [markdown]
# ### merge inspections with violations

# %%
# outer join to include only inspections with violations
df = pd.merge(df_inspections_simple, df_violations, on='ACTIVITY_NR')

# %%
df.head()
# Out:
#    ACTIVITY_NR                            ESTAB_NAME    SITE_CITY  SITE_ZIP  \
# 0    342934890  SPRINGFIELD FARM & HOME SUPPLY, INC.  SPRINGFIELD     62702
# 1    342934890  SPRINGFIELD FARM & HOME SUPPLY, INC.  SPRINGFIELD     62702
# 2    342934890  SPRINGFIELD FARM & HOME SUPPLY, INC.  SPRINGFIELD     62702
# 3    342934890  SPRINGFIELD FARM & HOME SUPPLY, INC.  SPRINGFIELD     62702
# 4    342934890  SPRINGFIELD FARM & HOME SUPPLY, INC.  SPRINGFIELD     62702
#
#            SITE_ADDRESS INSP_TYPE  INSP_DESC  Unnamed: 0 CITATION_ID  \
# 0  2804 N. DIRKSEN PKWY         B  Complaint           0      01001A
# 1  2804 N. DIRKSEN PKWY         B  Complaint           1      01001B
# 2  2804 N. DIRKSEN PKWY         B  Complaint           2      01002A
# 3  2804 N. DIRKSEN PKWY         B  Complaint           3      01002B
# 4  2804 N. DIRKSEN PKWY         B  Complaint          14      01001A
#
#   DELETE_FLAG  ... FTA_PENALTY FTA_CONTEST_DATE FTA_FINAL_ORDER_DATE HAZSUB1  \
# 0         NaN  ...         NaN              NaN                  NaN     NaN
# 1         NaN  ...         NaN              NaN                  NaN     NaN
# 2         NaN  ...         NaN              NaN                  NaN     NaN
# 3         NaN  ...         NaN              NaN                  NaN     NaN
# 4         NaN  ...         NaN              NaN                  NaN     NaN
#
#    HAZSUB2  HAZSUB3  HAZSUB4 HAZSUB5    LOAD_DT  RNUM
# 0      NaN      NaN      NaN     NaN  04-DEC-23     1
# 1      NaN      NaN      NaN     NaN  04-DEC-23     2
# 2      NaN      NaN      NaN     NaN  04-DEC-23     3
# 3      NaN      NaN      NaN     NaN  04-DEC-23     4
# 4      NaN      NaN      NaN     NaN  04-DEC-23     1
#
# [5 rows x 37 columns]

# %% [markdown]
# ### summarize violations by site

# %%
#count total number of complaints by site
df_violations_by_site = df.groupby(['SITE_ADDRESS','ESTAB_NAME']).agg({
    'ACTIVITY_NR': 'nunique',  # Count of unique inspections
    'CITATION_ID': 'count',  # Count of citations
    'INITIAL_PENALTY': 'sum',
    'CURRENT_PENALTY': 'sum', 
     'ISSUANCE_DATE': 'max'  # latest citation
})

# %% [markdown]
# ### top 10 offenders by number of citations

# %%
df_violations_by_site.head(10).sort_values(by='CITATION_ID', ascending=False)
# Out:
#                                                                   ACTIVITY_NR  \
# SITE_ADDRESS               ESTAB_NAME
# 1400 ADLAI STEVENSON DRIVE BUNN-O-MATIC CORPORATION                         1
# 1013 REYNOLDS STREET       CITY OF SPRINGFIELD - CWLP                       1
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                              2
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES                  1
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.            1
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC                1
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.              1
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.            1
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                         1
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                                1
#
#                                                                   CITATION_ID  \
# SITE_ADDRESS               ESTAB_NAME
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                       25-MAY-23
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES           20-APR-20
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.     21-AUG-18
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC         11-DEC-18
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.       17-MAY-18
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.     04-JUN-19
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                  20-APR-22
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                         19-NOV-21

# %% [markdown]
# ### top 10 offenders by total penalties

# %%
df_violations_by_site.head(10).sort_values(by='INITIAL_PENALTY', ascending=False)
# Out:
#                                                                   ACTIVITY_NR  \
# SITE_ADDRESS               ESTAB_NAME
# 1400 ADLAI STEVENSON DRIVE BUNN-O-MATIC CORPORATION                         1
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES                  1
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                              2
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC                1
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                         1
# 1013 REYNOLDS STREET       CITY OF SPRINGFIELD - CWLP                       1
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.            1
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.              1
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.            1
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                                1
#
#                                                                   CITATION_ID  \
# SITE_ADDRESS               ESTAB_NAME
# 1400 ADLAI STEVENSON DRIVE BUNN-O-MATIC CORPORATION                         9
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES                  3
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                              4
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC                2
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                         1
# 1013 REYNOLDS STREET       CITY OF SPRINGFIELD - CWLP                       4
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.            2
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.              2
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.            1
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                                1
#
#                                                                   INITIAL_PENALTY  \
# SITE_ADDRESS               ESTAB_NAME
# 1400 ADLAI STEVENSON DRIVE BUNN-O-MATIC CORPORATION                         59490
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES                  24598
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                              23897
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC                22173
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                         13674
# 1013 REYNOLDS STREET       CITY OF SPRINGFIELD - CWLP                        6600
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.             5174
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.               4434
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.                0
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                                    0
#
#                                                                   CURRENT_PENALTY  \
# SITE_ADDRESS               ESTAB_NAME
# 1400 ADLAI STEVENSON DRIVE BUNN-O-MATIC CORPORATION                       35109.0
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES                12300.0
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                            23004.0
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC              12934.0
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                        8204.0
# 1013 REYNOLDS STREET       CITY OF SPRINGFIELD - CWLP                      6600.0
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.           3000.0
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.             2000.0
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.              0.0
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                                  0.0
#
#                                                                  ISSUANCE_DATE
# SITE_ADDRESS               ESTAB_NAME
# 1400 ADLAI STEVENSON DRIVE BUNN-O-MATIC CORPORATION                  22-NOV-21
# 112 W. COOK                DAN GARREN DBA CYDE ENTERPRISES           20-APR-20
# 1500 TAYLOR AVE            NUDO PRODUCTS, INC.                       25-MAY-23
# 1110 STEVENSON DRIVE       CONTECH ENGINEERED SOLUTIONS, LLC         11-DEC-18
# 1200 BUNN AV.              BUNN-O-MATIC CORPORATION                  20-APR-22
# 1013 REYNOLDS STREET       CITY OF SPRINGFIELD - CWLP                10-SEP-21
# 1001 N 9TH STREET          GRIFFITTS EXTERIOR HOME DESIGNS, INC.     21-AUG-18
# 1308 S 2ND ST.             WEBER BUILDERS AND RENOVATORS, INC.       17-MAY-18
# 101 W. JEFFERSON           IL SECRETARY OF STATE - JEFFERSON ST.     04-JUN-19
# 1217 SOUTH 6TH STREET      BERG & ROBESON PC                         19-NOV-21

# %%
bunn_o_matic_initial = 59490 + 13674
bunn_o_matic_initial
# Out:
# 73164

# %%
bunn_o_matic_current = 35109 + 8204
bunn_o_matic_current
# Out:
# 43313
