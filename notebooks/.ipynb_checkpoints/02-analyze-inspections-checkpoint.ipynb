# %% [markdown]
# # Analyze OSHA Inspections for Springfield, IL 2018-2022
# 5 December 2023

# %% [markdown]
# ### Summary of Findings
# <ul>
#     <li><a href="https://www.osha.gov/enforcement/2022-enforcement-summary">Following national trends</a>, the number of OSHA inspections in Springfield, Illinois dropped to their lowest 5-year levels in 2020 and 2021 during the height of the COVID-19 pandemic.
#         <li>OHSA inspections based on employee complaints peaked in 2019 (n = 37) before dropping below pandemic levels in 2022 (n = 14)
#             <li>NUDO PRODUCTS, INC. at 1500 TAYLOR AVE has two complaint inspections, one in October 2018 and a second on June 2022
#                 <li>SOLOMON COLORS, INC. at 4050 NORTH COLOR PLANT RD has two complaint inspections from May 2020 to September 2021
#             </ul>

# %% [markdown]
# ### Next Steps for Improving This Analysis
# <ul>
#     <li>review specific violations for NUDO PRODUCTS and SOLOMON COLORS
#     <li>Explore individual complaints to understand spike in employee complaints in 2019
# <li>
# Contact a FOIA officer for an explanation of:
#     <ul>
#     <li>inspection type = M. This is not defined in the data dictionary at https://developer.dol.gov/health-and-safety/dol-osha-enforcement/#osha_inspection
#         <li>definition of "Complaint" inspection types. Is it accurate to say these are employee complaints, as suggested at https://www.osha.gov/enforcement/2022-enforcement-summary?
#     </ul>
# </ul>

# %% [markdown]
# # 1) Summarize OSHA Inspections

# %%
import pandas as pd

# %%
df_inspections = pd.read_csv("../data/springfield-il-inspections-2018-2022.csv")
#df_inspections.dtypes

# %%
#calculate YEAR for each inspection
df_inspections['OPEN_DATE'] = pd.to_datetime(df_inspections['OPEN_DATE'], format='%d-%b-%y')
df_inspections['YEAR'] = df_inspections['OPEN_DATE'].dt.year

# %%
#values for inspection code types are defined at
#https://developer.dol.gov/health-and-safety/dol-osha-enforcement/#osha_inspection
lkup_insp_type = lookup_table = {'A': 'Accident',
                                 'B': 'Complaint',
                                 'C': 'Referral',
                                 'D':'Monitoring',
                                 'E':'Evidence',
                                 'F':'Followup',
                                 'G':'Unprogrammed Related',
                                 'H': 'Planned',
                                 'I':'Programmed Related',
                                 'J':'Unprogrammed Other',
                                 'K':'Programmed Other',
                                 'L':'Other',
                                }

# %%
df_inspections['INSP_DESC'] = df_inspections['INSP_TYPE'].replace(lkup_insp_type)

# %%
df_inspections.to_csv("../data/springfield-il-inspections-2018-2022-edit.csv")

# %% [markdown]
# ### inspections by year by type

# %%
df_by_year = df_inspections.pivot_table(index=['INSP_TYPE','INSP_DESC'], columns='YEAR', values='ACTIVITY_NR', aggfunc='count')
df_by_year.reset_index(inplace=True)
#df_by_year.drop(columns=['YEAR'],inplace=True)
#df_by_year = df_by_year.rename_axis(index=None)
df_by_year
# Out:
# YEAR INSP_TYPE             INSP_DESC  2018  2019  2020  2021  2022
# 0            B             Complaint  31.0  37.0  18.0  18.0  14.0
# 1            C              Referral   4.0   4.0   2.0   8.0   7.0
# 2            D            Monitoring   NaN   NaN   NaN   1.0   4.0
# 3            F              Followup   NaN   NaN   NaN   NaN   2.0
# 4            G  Unprogrammed Related   1.0   1.0   1.0   2.0   NaN
# 5            H               Planned   3.0   7.0   3.0   1.0   7.0
# 6            I    Programmed Related   NaN   2.0   1.0   NaN   NaN
# 7            M                     M   NaN   4.0   1.0   2.0   1.0

# %% [markdown]
# ### total inspections by year

# %%
df_totals = df_by_year.sum(axis=0).reset_index()
df_totals
# Out:
#         YEAR                                                  0
# 0  INSP_TYPE                                           BCDFGHIM
# 1  INSP_DESC  ComplaintReferralMonitoringFollowupUnprogramme...
# 2       2018                                               39.0
# 3       2019                                               55.0
# 4       2020                                               26.0
# 5       2021                                               32.0
# 6       2022                                               35.0

# %% [markdown]
# ### complaint-related inspections

# %%
#df_inspections.dtypes

# %%
df_complaints = df_inspections[df_inspections['INSP_TYPE']=='C']
df_complaints.head()
# Out:
#     Unnamed: 0  ACTIVITY_NR  REPORTING_ID  STATE_FLAG  \
# 1            1    342965498        524500         NaN
# 28          28    343460580        524500         NaN
# 32          32    343509626        524500         NaN
# 34          34    343577128        524500         NaN
# 73          73    344113766        524500         NaN
#
#                             ESTAB_NAME                 SITE_ADDRESS  \
# 1             FRIENDLY CHEVROLET, INC.  2450 PRAIRIE CROSSING DRIVE
# 28   CONTECH ENGINEERED SOLUTIONS, LLC         1110 STEVENSON DRIVE
# 32  MICHEL CONCRETE CONSTRUCTION, INC.      3101 GREAT NORTHERN RD.
# 34                 NUDO PRODUCTS, INC.              1500 TAYLOR AVE
# 73                  UNKNOWN CONTRACTOR          1123 N FRANKLIN AVE
#
#       SITE_CITY SITE_STATE  SITE_ZIP OWNER_TYPE  ...        HOST_EST_KEY  \
# 1   SPRINGFIELD         IL     62711          A  ...  HOST_EST_KEY_VALUE
# 28  SPRINGFIELD         IL     62703          A  ...  HOST_EST_KEY_VALUE
# 32  SPRINGFIELD         IL     62711          A  ...  HOST_EST_KEY_VALUE
# 34  SPRINGFIELD         IL     62703          A  ...  HOST_EST_KEY_VALUE
# 73  SPRINGFIELD         IL     62701          A  ...  HOST_EST_KEY_VALUE
#
#    NR_IN_ESTAB  OPEN_DATE  CASE_MOD_DATE  CLOSE_CONF_DATE CLOSE_CASE_DATE  \
# 1           90 2018-02-22      03-DEC-23        22-FEB-18       16-MAY-19
# 28          39 2018-09-13      03-DEC-23        07-DEC-18       22-JAN-19
# 32           4 2018-10-02      03-DEC-23        02-OCT-18       06-FEB-19
# 34         167 2018-10-30      03-DEC-23        30-OCT-18       07-FEB-19
# 73           0 2019-06-14      03-DEC-23        14-JUN-19       27-JUN-19
#
#       LOAD_DT RNUM  YEAR  INSP_DESC
# 1   04-DEC-23    2  2018   Referral
# 28  04-DEC-23   29  2018   Referral
# 32  04-DEC-23   33  2018   Referral
# 34  04-DEC-23   35  2018   Referral
# 73  04-DEC-23   74  2019   Referral
#
# [5 rows x 40 columns]

# %%
#count total number of complaints by site
df_complaints_by_site = df_complaints.groupby(['SITE_ADDRESS','ESTAB_NAME']).agg({
    'ACTIVITY_NR': 'count',  # Count of 'ACTIVITY_NR'
    'OPEN_DATE': ['min', 'max']  # Minimum and maximum of 'OPEN_DATE'   
})
df_complaints_by_site
# Out:
#                                                                                  ACTIVITY_NR  \
#                                                                                        count
# SITE_ADDRESS                              ESTAB_NAME
# 1100 LEJUNE DRIVE                         WALMART INC.                                     1
# 1110 STEVENSON DRIVE                      CONTECH ENGINEERED SOLUTIONS, LLC                1
# 1123 N FRANKLIN AVE                       UNKNOWN CONTRACTOR                               1
# 1200 BUNN AV.                             BUNN-O-MATIC CORPORATION                         1
# 1500 TAYLOR AVE                           NUDO PRODUCTS, INC.                              2
# 2201 TORONTO RD.                          HENSON ROBINSON COMPANY                          1
# 2318 WABASH AVE                           RESTAURANT EQUIPMENT SERVICE GROUP LLC           1
# 2450 PRAIRIE CROSSING DRIVE               FRIENDLY CHEVROLET, INC.                         1
# 2601 COLT ROAD                            PRAIRIE SMOKEHOUSE PARTNERS, LLC                 1
# 2850 CIDER MILL LANE                      E.L. PRUITT COMPANY                              1
# 3013 FOX BRIDGE ROAD                      UNITED STATES POSTAL SERVICE                     1
# 310 E WASHINGTON STREET                   GREEN DEMOLITION CONTRACTORS, INC.               1
# 3101 GREAT NORTHERN RD.                   MICHEL CONCRETE CONSTRUCTION, INC.               1
# 3101 SOUTH VETERANS PARKWAY               KING-LAR ROOFING, INC.                           1
# 3400 WEST WASHINGTON                      LEWIS MEMORIAL CHRISTIAN VILLAGE                 1
# 4050 NORTH COLOR PLANT RD                 SOLOMON COLORS, INC.                             2
# 4050 NORTH COLOR PLANT ROAD               PERSONNEL PLACEMENT INC                          1
# 4840 JEFFORY STREET                       CAVALIER CARTAGE CO.                             1
# 501 S. GRAND AVE.                         BRE SOGRAND, INC.                                1
# 525 SOUTH MARTIN LUTHER KING JUNIOR DRIVE AVENUES AT ARCADIA SPRINGFIELD, LLC              1
# 580 NORTH ST.                             CAST INDUSTRIES, INC.                            1
# 701 N FIRST STREET                        THORNBURGH ABATEMENT, INC.                       1
# 993 CLOCKTOWER DRIVE, SUITE D             ARENA FOOD SERVICE, INC.                         1
#
#                                                                                   OPEN_DATE  \
#                                                                                         min
# SITE_ADDRESS                              ESTAB_NAME
# 1100 LEJUNE DRIVE                         WALMART INC.                           2022-11-29
# 1110 STEVENSON DRIVE                      CONTECH ENGINEERED SOLUTIONS, LLC      2018-09-13
# 1123 N FRANKLIN AVE                       UNKNOWN CONTRACTOR                     2019-06-14
# 1200 BUNN AV.                             BUNN-O-MATIC CORPORATION               2022-02-24
# 1500 TAYLOR AVE                           NUDO PRODUCTS, INC.                    2018-10-30
# 2201 TORONTO RD.                          HENSON ROBINSON COMPANY                2019-10-09
# 2318 WABASH AVE                           RESTAURANT EQUIPMENT SERVICE GROUP LLC 2021-03-26
# 2450 PRAIRIE CROSSING DRIVE               FRIENDLY CHEVROLET, INC.               2018-02-22
# 2601 COLT ROAD                            PRAIRIE SMOKEHOUSE PARTNERS, LLC       2021-11-10
# 2850 CIDER MILL LANE                      E.L. PRUITT COMPANY                    2021-07-14
# 3013 FOX BRIDGE ROAD                      UNITED STATES POSTAL SERVICE           2021-02-12
# 310 E WASHINGTON STREET                   GREEN DEMOLITION CONTRACTORS, INC.     2022-04-21
# 3101 GREAT NORTHERN RD.                   MICHEL CONCRETE CONSTRUCTION, INC.     2018-10-02
# 3101 SOUTH VETERANS PARKWAY               KING-LAR ROOFING, INC.                 2022-02-09
# 3400 WEST WASHINGTON                      LEWIS MEMORIAL CHRISTIAN VILLAGE       2020-12-10
# 4050 NORTH COLOR PLANT RD                 SOLOMON COLORS, INC.                   2020-05-19
# 4050 NORTH COLOR PLANT ROAD               PERSONNEL PLACEMENT INC                2021-11-30
# 4840 JEFFORY STREET                       CAVALIER CARTAGE CO.                   2021-03-16
# 501 S. GRAND AVE.                         BRE SOGRAND, INC.                      2022-05-11
# 525 SOUTH MARTIN LUTHER KING JUNIOR DRIVE AVENUES AT ARCADIA SPRINGFIELD, LLC    2022-06-17
# 580 NORTH ST.                             CAST INDUSTRIES, INC.                  2021-08-31
# 701 N FIRST STREET                        THORNBURGH ABATEMENT, INC.             2019-06-26
# 993 CLOCKTOWER DRIVE, SUITE D             ARENA FOOD SERVICE, INC.               2019-08-23
#
#
#                                                                                         max
# SITE_ADDRESS                              ESTAB_NAME
# 1100 LEJUNE DRIVE                         WALMART INC.                           2022-11-29
# 1110 STEVENSON DRIVE                      CONTECH ENGINEERED SOLUTIONS, LLC      2018-09-13
# 1123 N FRANKLIN AVE                       UNKNOWN CONTRACTOR                     2019-06-14
# 1200 BUNN AV.                             BUNN-O-MATIC CORPORATION               2022-02-24
# 1500 TAYLOR AVE                           NUDO PRODUCTS, INC.                    2022-06-29
# 2201 TORONTO RD.                          HENSON ROBINSON COMPANY                2019-10-09
# 2318 WABASH AVE                           RESTAURANT EQUIPMENT SERVICE GROUP LLC 2021-03-26
# 2450 PRAIRIE CROSSING DRIVE               FRIENDLY CHEVROLET, INC.               2018-02-22
# 2601 COLT ROAD                            PRAIRIE SMOKEHOUSE PARTNERS, LLC       2021-11-10
# 2850 CIDER MILL LANE                      E.L. PRUITT COMPANY                    2021-07-14
# 3013 FOX BRIDGE ROAD                      UNITED STATES POSTAL SERVICE           2021-02-12
# 310 E WASHINGTON STREET                   GREEN DEMOLITION CONTRACTORS, INC.     2022-04-21
# 3101 GREAT NORTHERN RD.                   MICHEL CONCRETE CONSTRUCTION, INC.     2018-10-02
# 3101 SOUTH VETERANS PARKWAY               KING-LAR ROOFING, INC.                 2022-02-09
# 3400 WEST WASHINGTON                      LEWIS MEMORIAL CHRISTIAN VILLAGE       2020-12-10
# 4050 NORTH COLOR PLANT RD                 SOLOMON COLORS, INC.                   2021-09-28
# 4050 NORTH COLOR PLANT ROAD               PERSONNEL PLACEMENT INC                2021-11-30
# 4840 JEFFORY STREET                       CAVALIER CARTAGE CO.                   2021-03-16
# 501 S. GRAND AVE.                         BRE SOGRAND, INC.                      2022-05-11
# 525 SOUTH MARTIN LUTHER KING JUNIOR DRIVE AVENUES AT ARCADIA SPRINGFIELD, LLC    2022-06-17
# 580 NORTH ST.                             CAST INDUSTRIES, INC.                  2021-08-31
# 701 N FIRST STREET                        THORNBURGH ABATEMENT, INC.             2019-06-26
# 993 CLOCKTOWER DRIVE, SUITE D             ARENA FOOD SERVICE, INC.               2019-08-23
